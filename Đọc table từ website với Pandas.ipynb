# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 393.8 kB/s eta 0:00:10
#    - -------------------------------------- 0.1/3.8 MB 798.9 kB/s eta 0:00:05
#    - -------------------------------------- 0.2/3.8 MB 952.6 kB/s eta 0:00:04
#    - -------------------------------------- 0.2/3.8 MB 952.6 kB/s eta 0:00:04
#    --- ------------------------------------ 0.3/3.8 MB 1.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.4/3.8 MB 1.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.5/3.8 MB 1.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.5/3.8 MB 1.2 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 1.3 MB/s eta 0:00:03
# ...

# %%
# Đọc HTML
import pandas as pd
table = pd.read_html('https://www.hnx.vn/co-phieu-etfs/du-lieu-thi-truong-ny-quy-mo.html')
table[0]
# Out:
#   STT Mã CK Đặt mua                            Đặt bán             \
#   STT Mã CK Số lệnh Khối lượng  Giá trị (Đồng) Số lệnh Khối lượng
# 0   1   AAV     880  4.850.195  32.418.701.700     735  5.747.416
# 1   2   ADC      14      3.975      69.790.600      10      8.535
# 2   3   ALT      16        662      10.876.400      20     13.124
# 3   4   AMC       7      3.814      64.112.000       4      1.900
# 4   5   AME       3        300       2.050.000      10      6.301
# 5   6   AMV     457  2.690.884   9.148.337.700     842  4.078.185
# 6   7   API     166    625.519   2.738.018.200     174  1.127.754
# 7   8   APS     332    755.980   4.353.047.800     445  1.573.647
# 8   9   ARM       1          1          34.900       4        884
# 9  10   ATS       1        100       1.220.000       2        400
#
#                   Khớp lệnh liên tục                 Khớp lệnh định kỳ  \
#    Giá trị (Đồng)         Khối lượng  Giá trị (Đồng)        Khối lượng
# ...

# %%
table = pd.read_html('https://webgia.com/')
table[0]
# table[1]
# table[2]
# table[3]
# table[4]
# Out:
#            Khu vực            Hệ thống             Mua vào              Bán ra
# 0   TP.Hồ Chí Minh                 SJC           8.880.000           9.130.000
# 1   TP.Hồ Chí Minh                 PNJ           8.880.000           9.130.000
# 2   TP.Hồ Chí Minh                DOJI           8.770.000           8.920.000
# 3   TP.Hồ Chí Minh             Mi Hồng           8.680.000           8.930.000
# 4   TP.Hồ Chí Minh           Ngọc Thẩm           8.600.000           8.950.000
# 5         Biên Hòa                 SJC             web giá             web giá
# 6           Hà Nội                 PNJ  xem tại webgia.com          webgiá.com
# 7           Hà Nội                DOJI          webgia.com          webgia.com
# 8           Hà Nội   Bảo Tín Minh Châu  xem tại webgia.com  xem tại webgia.com
# 9           Hà Nội    Bảo Tín Mạnh Hải             web giá          webgiá.com
# 10          Hà Nội             Phú Quý             web giá             web giá
# ...
